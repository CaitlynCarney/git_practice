# %% [markdown]
# # Clustering
#
# Try to understand this really well
# ![image.png](attachment:79ea3b60-36da-4ed4-8d92-e50ee38bbaa9.png)

# %% [markdown]
# Lets look at some examples:
# - customer sergmentation marketing
#     - lets say we have all these customers and want to group them based on what they use our store for
#     - identify different types of shoppers
#         - produce buyer
#         - everything buyers
#         - perscription buyers
#     - I want to group them with machine learning
#         - it would take forever to do this manually cause we have a lot of customers
#     - Can tell us a customers and b customers and c customers
#     - Can use clustering to idntify threats in an enviornment.
#         - people who are accessing files they should not be accessing based on:
#             - their role
#             - their dept
#             - how often are they accessing them
#                 - these files could be
#             - HR files
#             - python files
#             - etc.
#     - identify themes of survey responses
#         - you wouldnt know what to look at yet
#         - so the algoristh will find themes that you dont know about
#     - what are the diffrent subject of these photots
#         - looks for similar shapes
#         - what do each cluster consist of
#             - this part you do yourself
#                 - this group's samples are filled with people therefore it is the people cluster
#                 - this one is dogs
#                 - this one is chickens
#                 - etc.

# %% [markdown]
# ### Learning Goals
# 1. Be able to discuss and discover use cases for clustering across multiple industries.
#     - discuss the cases used clustering
# 2. Be able to recognize of common clustering algorithms.
# 3. General understanding of how the k-means clustering algorithm works.
#     - be able to talk through it in like 3 steps
#         - not in great detail
# 4. Ability to implement k-means clustering in python.
# 5. Handle outliers using IQR.
# 6. More practice scaling data.
#     - because clustering uses the distance between points
#         - whenever you use distance it is important your units are on the same scale
# 7. Strategies for missing values.
# 8. Plotting clusters.
#     - so you can explore them
# 9. Ability to make use of clusters discovered later down the data science pipeline.
#     - we find clusters
#         - now what?
#             - How does this really work in practice?
#                 - YOUR PROJECT WILL USE THIS!

# %% [markdown]
# ### About Clustering
# ![image.png](attachment:c96c94c8-453d-4a3b-863e-8634f2c00a5a.png)

# %% [markdown]
# How does it fit into machine learning?
# - It is a Unsupervised ML
# - MLP can use clustering
# - Anomaoly detection can use clustering
#
# - Algorithsm that use it:
#     - k means
#     - dacam
#     - theortical

# %% [markdown]
# ### Clustering is...
#
# - **Unsupervised** machine learning methodology
#     - Used to group and identify similar observations when we do not have labels that identify the groups.
# - Often a preprocessing or an exploratory step in the data science pipeline.
#     - generally not the last step
#         - it is a piece to insert in the middle to optimize your work.
#         - going to enhance your work
#         - sometimes done just for the point of I dont know what I have here.
#         - can be used to enhance your linear regression models
#             - or other models.
#                 - what if we decide each cluster needs its own model?
#                 - identify clusters and 2 of them lead to very different results so we make them into 3 different dummy variables that feed into the model
#                 - we can make cluster to identify what it is and assign new observations to these clusters
#                     - so what was unsup now has labels so becomes a classification because we have developed the classse
#
# Suppose you have a data set with observations, features, but no labels or target variable.
#
# **You want to predict which group of similar observations a new observation will fall in.**
# - Without the labels, you cannot use a supervised algorithm, such as a random forest or KNN.
#     - so we can find these clusters take some samples, lable them, create or classes
# - We can address this challenge by finding groups of data in our dataset which are similar to one another. These groups are called clusters.
#
# Clustering can also be used for **data exploration**, or to **generate a new feature** that can then be fed into a supervised model.
# - generate new features
#
# Formally, clustering is an **unsupervised process** of grouping similar observations or objects together. In this process similarities are based on comparing a vector of information for each observation or object, often using various mathematical distance functions.

# %% [markdown]
# ### Clustering methodologies include:
# - Partitioned based clustering (K-Means)
#     - where are these partitions?
#     - where shosuld they be srawn
#         - ![image.png](attachment:c282a7a5-718d-479d-81d6-d14942f88e97.png)
# - Hierarchical clustering
#     - jsut as you would think. A heirarchy.
#         - think of an organization structure
#             - I report to someone who reports to some who reports to someone
#                 - you are the first cluster (the analytics team)
#                 - that first person you report to is your second ( marketing team)
#                 - they report to the next 3rd cluster (the company)
#         - ![image.png](attachment:d40c44ec-8114-4da7-8460-467ef20aa87c.png)
# - Density-based clustering (Density-Based Spatial Clustering of Applications with Noise (DBSCAN))
#     - talk about later
#     - is maggie's fav.
#
# Every methodology follows a different set of rules for defining the ‘similarity’ among data points.
#
# While there are more than 100 known clustering algorithms, few of the algorithms are popularly used, and we will be focusing on K-means in the coming lesson.
#
# - ultimatly it is ataking an input of variables and grouping observations that are most similar
#     - all about how you define similar

# %% [markdown]
# ### Clustering Use Cases
# - Text: Document classification, summarization, topic modeling, recommendations
# - Geographic: Crime zones, housing prices
# - Marketing: Customer segmentation, market research
# - Anomaly Detection: Account takeover, security risk, fraud
# - Image Processing: Radiology, security

# %% [markdown]
# ### Hospital distance cluster example

# %% [markdown]
# ![image.png](attachment:344cd59d-a510-404b-8643-296ffa3872a0.png)

# %% [markdown]
# ## Vocabulary
# ### Euclidean Distance
#
# **The shortest distance between two points in n-dimensional space, a.k.a. L2 distance.**
#
# < *span* >< *spanclass* =" *MathJaxPreview* "> *√∑ni=1(qi−pi)2* < */span* >< *scripttype* =" *math/tex* "> *√∑ni=1(qi−pi)2*

# %% [markdown]
# ### Manhattan Distance
#
# **The distance between two points is the sum of the absolute differences of their Cartesian coordinates. **
#
# Also known as:
# - taxicab metric
# - rectilinear distance
# - ![Screen Shot 2021-03-25 at 11.19.26 AM.png](attachment:2ac0e1f0-d8e5-4f6e-8ed6-ca3cb7ff7eab.png) distance
# - ![Screen Shot 2021-03-25 at 11.19.43 AM.png](attachment:25a01c06-98c7-4747-afd0-d9bbdbef0f3e.png) distance or ![Screen Shot 2021-03-25 at 11.20.06 AM.png](attachment:e6fe6297-cc05-4711-9f45-eca98b5a54b1.png) norm
# - snake distance
# - city block distance
# - Manhattan length.

# %% [markdown]
# ### Cosine Similarity
#
# **Cosine Similarity measures the cosine of the angle between two vectors to define similarity between two vectors. **
#
# - a way to compare vectors base don the direction they are pointing in
#     - so if you have 2 vectors pointing in the same direction
#         - think of 2 parralel lines
#             - these are as similar as they can be
#     - what if they were going in opposite directions
#         - but if you have 2 perpendicular lines
#             - they are as diffrent as they can be
#     - similar to correlation in a sense
#     - can be done with texting and similar words
#         - they found that man sat on the same vector as doctor
#         - women sat on the same vector as nurse
#             - and all this cam from texts
#
#
# It is a measure of orientation and not magnitude: two vectors with the same orientation, i.e. parallel, have a cosine similarity of 1 indicating they are maximally "similar".
#
# Two vectors oriented at 90° relative to each other, i.e. perpendicular or orthogonal, have a similarity of 0 and are considered maximally "dissimilar".
#
# If two vectors diametrically opposed (180∘) have a similarity of -1. The cosine similarity is particularly used where the outcome is neatly bounded in [0,1].

# %% [markdown]
# ### Sparse vs. Desnse Matrix
#
# A sparse matrix is a matrix in which most of the elements are zero. By contrast, if most of the elements are nonzero, then the matrix is considered dense.
#
# The number of zero-valued elements divided by the total number of elements (e.g., m × n for an m × n matrix) is called the **sparsity** of the matrix (which is equal to 1 minus the density of the matrix). Using those definitions, a matrix will be sparse when its sparsity is greater than 0.5.
#
# - this is one where most of the entries are 0
#     - then there are a few 1's
# - a dense Matrix is not a sparse Matrix
#
# May refer to this later

# %% [markdown]
# ### Manhattan (Taxicab) vs Euclidean Distance
#
# ![image.png](attachment:98362f35-b72e-4773-8996-006b4cc6918a.png)
#
# - blue yellow red are all manhatan and the green is Euclidean
#
# In taxicab geometry, the red, yellow, and blue paths all have the same shortest path length of 12. In Euclidean geometry, the green line has length 6√2≈8.49 and is the unique shortest path.

# %% [markdown]
# ### Data Types
#
# - Input:
#     - Continuous data
#         - usually
#     - ordered discrete data at a minimum.
#         - minimum
# - Output:
#     - Integer representing a cluster id.
#         - The number itself doesn't mean anything except that those who share the same number are most similar.
#         - In addition, the number doesn't compare to any of the other cluster id's beyond the fact that they are different.
#         - cluster 1 is not less than cluster 5
#             - it could be cluster A
#                 - It is just a lable
#         - once we get the clusters and deem them important
#             - go through them and assign them a label
#                 - example
#                     - dog
#                     - fresh food buyer

# %% [markdown]
# ## Common Clustering Agorithms
#
# ![image.png](attachment:a14b3fbc-69b9-40b1-89e0-9bc900c5a4fa.png)

# %% [markdown]
# - k mean will find the enter point
#     - determine each data points cluster based off distance from each point it created
# - DBSCAN
#     - kind of takes care of outliers at the same time
#     - great for anomoly detections

# %% [markdown]
# ## K-Means
# ![image.png](attachment:a130343b-420d-40ec-811d-99e44ba71b78.png)

# %% [markdown]
# - K = 10 up above
#     - this was a hyper parameter made before hand
# - Most popular "clustering" algorithm.
# - Stores K centroids that it uses to define clusters.
#     - a point is considered part of the cluster if it is closer to it than any other centroids
#         - will find a new one and keep moving throught the points
# - A point is considered to be in a particular cluster if it is closer to that cluster's centroid than any other centroid.
# - K-Means finds the best centroids by alternating between (1) assigning data points to clusters based on the current centroids, and (2) choosing centroids (points which are the center of a cluster) based on the current assignment of data points to clusters.
# - Python implementation: sklearn.cluster.KMeans
#     - https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %% [markdown]
# #### Key Hyperparameters
#
# - **Number of Clusters (k): **
#     - The number of clusters to form, which is equal to the number of centroids to generate.
#         - VERY IMPORTANT
#
# - `random_state`:
#     - Specific to sklearn, this is for 'setting the seed' for reproducibility. When you use any integer as a value here and then re-run with the same value, the algorithm will kick off with the same seed as before, thus the same observations & centroids.
#         - if you dont set it it wont start with the same centroids
#             - or else it will give you complety different clusters each time.

# %% [markdown]
# #### Pros of K-Means
#
# - Performance scales well with the amount of data, i.e. the algorithm is linear in the number of objects O(n).
#
# - Creates tighter, more refined clusters.
#
# - Centroids can be recomputed driving an observation or object to another cluster.
#     - it is very adaptable

# %% [markdown]
# #### Cons of K-Means
#
# - Naive use of the mean value for the cluster center.
#
# - Fails when the clusters are not circular.
#     - you will run into a lot of challenges
#
# - Hard to predict what K (the number of clusters) should be.
#     - methods to get around that which we will go over
#
# - Which observations the clustering starts with, i.e. initial seeds, can dramatically affect the results.
#     - if you dont set random state and do a different one you can get very different results
#         - which can be a big challenge
#
# - The order of the data can affect the results.
#     - because it is assigning one at a time
#
# - Results are extremely sensitive to the scale of the data.
#     - super important to scale the data

# %% [markdown]
# ## Hierarchical Clustering
# ![image.png](attachment:11f4ce04-36cd-44c2-a5cc-cd20e16f052e.png)

# %% [markdown]
# - **Bottom-up Clustering**:
#     - Each observation is its own cluster (bottom) and clusters are merged as they move "up" the hierarchy, a.k.a. hierarchical agglomerative clustering.
#     - sklearn.cluster.AgglomerativeClustering
#         - I pick up a spoon and put it with the forks then I pick a bowl and it goes with the plate
#
# - **Top-down Clustering**:
#     - All observations start in a single cluster (top) and is split appart recursively as it moves "down" the hierarchy, a.k.a. hierarchical divisive clustering.
#         - I start with all the dishes and see there are utensils and broke them up into spoons forks and knifes.
#
# - Can be intensive
#
# - Good fits for hierarchical clustering: Customers' preferred support channels, classifying biological species, like the animal species, shopping cart analysis.

# %% [markdown]
# ### Key Hyperparameters
#
# - **Linkage**: Determines which distance to use between sets of observations.
#
#     - ward:
#         - Looks for clusters that are very cohesive inside and extremely differentiated from other groups. It tends to find clusters of similar size. Only uses Euclidean distance metric.
#
#     - average:
#         - Uses the clusters centroids or the average of the distances of each observation of the two sets. Clusters can be of different sizes and shapes.
#
#     - complete or maximum linkage:
#         - Uses the maximum distances between all observations of the two sets, or the most dissimilar observations. This leads to more dense clusters.
#
#     - single:
#         - Uses the minimum of the distances between all observations of the two sets.
#
# - **Affinity**: How distance is defined in the algorithm, i.e. which distance calculation is used.
#
#     - Euclidean Distance (euclidean or L2 options):
#         - Shortest distance between two points, the shortest route, as if your were flying a plane from one point to the next.
#
#     - Manhattan Distance (manhattan or L1 options):
#         - Requires movements that are parallel to the x or y axis at any given time, as if you were driving in a car in manhattan along the grid-like streets.
#
#     - Cosine Similarity (cosine option):
#         - Puts emphasis on the 'shape' of the variables rather than their values, so it will associate observations that have similar min and max variables, e.g. Cosine Similarity is a good option when you have high dimensionality, i.e. many variables. This is often used in measuring similarity of text.

# %% [markdown]
# ### Pros of Hierarchical Clustering
#
# - Deciding the number of clusters is intuitive by looking at the dendrogram that is created.
#
# - Relatively easy to implement.

# %% [markdown]
# #### Cons of Hierarchical Clustering
#
# - Performance does not scale well with amount of data, i.e. the algorithm is quadratic in the number of objects O(n2).
#
# - Less adaptable, i.e. once an instance is assigned to a cluster it cannot be moved around.
#
# - Ability to perform on large datasets is challenging, if not impossible.
#
# - Highly sensitive to outliers.
#
# - The observations which the clustering starts with, i.e. initial seeds, can dramatically affect the results.
#
# - The order of the data can affect the results.

# %% [markdown]
# ## DBSCAN
#
# - DBSCAN: **Density-Based Spatial Clustering** of Applications with Noise
#
#     - Clusters together objects based on the density of the space around them.
#         - so those with many neighbors will be clustered together
#         - those not near any will not be clustered together
#
#     - Those with many neighbors will be clustered together, while objects sitting in a low density space will not be placed in a cluster.
#
#     - sklearn.cluster.DBSCAN
#         - https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN

# %% [markdown]
# ### Key Hyperparameters
#
# - If *p* is the point derived from the vector of an object (i.e. the vector of an observation), the minimum number of points (minPts) must be within a radius of ϵ from p.
#     - These parameters must be specified by the user.
#
# - **Epsilon ϵ** (`eps`):
#     - Can be estimated using a k-distance graph, looking for the elbow in the graph.

# %% [markdown]
# **Minimum Points** minPts (`min_samples`): Can be estimated by the number of dimensions,D, in the dataset.
#
# - minPts ≥ D + 1 ⋀ minPts ≥ 3
#
# - minPts = 2 × D is generally a good estimate.
#
# - For larger datasets or those with more outliers, however, a value greater than that may be needed.

# %% [markdown]
# ### Distance Metrics metric:
#     - sklearn.metrics.pairwise_distances
#         - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise_distances
#
# - Euclidean Distance (euclidean or L2 options):
#     - Shortest distance between two points, the shortest route, as if your were flying a plane from one point to the next.
#
# - Manhattan Distance (manhattan, L1, or cityblock options):
#     - Requires movements that are parallel to the x or y axis at any given time, as if you were driving in a car in Manhattan along the grid-like streets.
#
# - Cosine Similarity (cosine option):
#     - Puts emphasis on the 'shape' of the variables rather than their values, so it will associate observations that have similar min and max variables, e.g. Cosine Similarity is a good option when you have high dimensionality, i.e. many variables. This is often used in measuring similarity of text.

# %% [markdown]
# ### Pros of DBSCAN
#
# - Doesn't require pre-set number of clusters.
# - Identifies outliers as noise.
# - Able to find arbitrarily sized and arbitrarily shaped clusters.
# - Requires only 2 parameters.
# - Is not largely affected by the order of the data.

# %% [markdown]
# ### Cons of DBSCAN
#
# - Performance does not scale well with amount of data; however, performance can improve with indexing. The worst case scenario is O(n2).
# - Doesn't do as well with clusters of varying density.
# - Not great with very high-dimensional data because the distance threshold, epsilon, becomes challenging to estimate.
# - When an object sits on the border of more than one cluster, the cluster is determined by the order of the data.

# %% [markdown]
# ### Further Reading
# - Wikipedia: Cosine Similarity
#     - https://en.wikipedia.org/wiki/Cosine_similarity
# - Wikipedia: Sparse Matrix
#     - https://en.wikipedia.org/wiki/Sparse_matrix
# - Wikipedia: Taxicab Geometry
#     - https://en.wikipedia.org/wiki/Taxicab_geometry
# - A short kmeans example
#     - http://stanford.edu/~cpiech/cs221/handouts/kmeans.html
# - Kmeans Visualization
#     - http://web.stanford.edu/class/ee103/visualizations/kmeans/kmeans.html
# - Interactive k-means demo
#     - https://www.naftaliharris.com/blog/visualizing-k-means-clustering/
# - DBSCAN Interactive Demo
#     - https://www.naftaliharris.com/blog/visualizing-dbscan-clustering/
