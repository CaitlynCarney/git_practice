# %% [markdown]
# Hypothesis testing is the process of comparing one hypothesis to another, and using statistics to help evaluate the hypothesis.
#
# In this lesson we will introduce some broad concepts related to hypothesis testing, and in future lessons we will look at examples of 3 types of hypothesis tests in detail.
#
# The terms covered in this lesson are summarized in the table below:

# %% [markdown]
# ![Screen%20Shot%202021-02-11%20at%209.12.12%20AM.png](attachment:Screen%20Shot%202021-02-11%20at%209.12.12%20AM.png)

# %% [markdown]
# **Null hypothesis**
# - is the hypothesis that there is no difference etween groups
#     - no correlation
#     - no change
#     - no effect
#     - no difference
#
# we set up our environment to either reject the null hypothesis or fail to reject it.
#
# Null hypothesis is that thes is null difference, null effect, null relatioship between things we're measuring.

# %% [markdown]
# **Alternative Hypothesis**
# - if it is not null what is the other hypothesis
#
# ex:
#    - codeup data science drink more coffee than web dev students
#         - null hypothesis : there is no difference and they have the same consumption rate
#         - althernative hypothesis : consumption rate is diffence

# %% [markdown]
# **Significance Level, False Positive Rate**
# - P(FP) = P(Type I Error)
#
#         - alpha = 1 - confidence level
#             a = 1 - (what is our threshold for accpeptoing findings even if they're random)
#
#         - lets set our confidence level to be 95%
#             . a = 1 - .95 = .05
#
#         - lets set our confidence level to be 99%
#             . a = 1 - .99 = .01
#
#         - set your confidence level and your alpha before you run any experiment
#
# - alpha is your false positive rate
#     - type 1 error
#
# Lower alpha means lower toletance for getting the results we get from chance/randomness
# - if you crank it way down to .999 it is crazy
#     - a = 1 - .999 = 0.001

# %% [markdown]
# **Statistical Power**
# - P(Reject H0 when H0 is false)
#
# - Beta is your false negative rate
#     - type 2 error
#
#
# **False Negative Rate**
#     - P(FN) = P(Type II Error)
#
# **p-value**
#     - P(We observed this result due to chance | H0 is true)

# %% [markdown]
# boy who cried wolf and hypothesis testing
# - type one error
#     - boy cries wolf ( making hypothesis)
#         - villagers believe it
#             - but its not the case
#                 - false alarm
#                     - false positive
#                         - type 1 error
#     - boy cries wolf second time (no actual wolf)
#         - villagesrs make another false alarm ( type 1 error)
# - type 2 error
#     - boy cries wolf, but there is a wolf
#         - villagers disbelieve the hypothesis
#             - but the wolf is real
#                 -  False Negative
#                     - another way to say "false negative" is a miss
#
# **True/False is the relity**
# **Positive/Negative is the prediction**
#
# Car engine light hypothesis testing
# - check engine lights stays off, but your engine actually has a problem
#     - True Positive = Check engine light goes off and there is a probelm
#     - True Negative = check engine light stays off
#     - False Positive = false alarm( engine light, but no problem)
#     - False Negative = miss = engine light stays off but there is a problem

# %% [markdown]
# if p < alpha:
# - print("reject the null hypothesis")
# esle:
# - print("Fail to reject the null hypothesis")

# %% [markdown]
# In general hypothesis tests are performed like so:
#
# 1. Choose the right type of test for your data / question1
# 2. Set a desired confidence level and form hyoptheses
# 3. Calculate the appropriate test statistics and p-value
# 4. Conclude based on the above statistics

# %% [markdown]
# ## Central Limit Theorem
#
# The central limit theorem tells us that the **sampling distribution** for a random variable is normally distributed, even if the underlying random variable is not.
#
# Let's take the example of rolling a dice. We know that rolling a die is a random process, but imagine an experiment where we roll 10 dice and take the average roll. If we performed this experiment many times and plotted the resulting calculated averages of 10 dice rolls, we would expect to see a normal distribution.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)

n_dice_per_experiment = ncols = 10
n_experiments = nrows = 100

data = np.random.randint(1, 7, (nrows, ncols))

data[:4]
# Out:
# array([[6, 3, 5, 3, 2, 4, 3, 4, 2, 2],
#        [1, 2, 2, 1, 1, 2, 4, 6, 5, 1],
#        [1, 5, 2, 4, 3, 5, 3, 5, 1, 6],
#        [1, 2, 4, 5, 5, 5, 2, 6, 4, 3]])

# %%
calculated_averages = data.mean(axis=1)

# %%
calculated_averages
# Out:
# array([3.4, 2.5, 3.5, 3.7, 3.2, 4.7, 3.4, 3.2, 3.4, 3. , 3.7, 3.5, 4. ,
#        4.5, 2.9, 2.8, 2.9, 3.8, 3.2, 3.6, 3.4, 4. , 3.5, 3.3, 3.6, 3. ,
#        4.3, 3. , 3.3, 3.2, 4.2, 3.9, 3.2, 3.8, 3.6, 3.4, 2.7, 3.4, 3.2,
#        3.1, 3.2, 3. , 4.1, 3.3, 3. , 4.1, 3.4, 3.3, 2.9, 3.8, 3.4, 3.6,
#        3.9, 3.2, 4.7, 3.8, 3.5, 2.8, 3.8, 4.7, 4.1, 3.5, 2.8, 3.7, 3.4,
#        3.7, 3.6, 4.1, 3.6, 3.5, 2.9, 4. , 3.2, 3.4, 4.4, 2.9, 3.2, 3.9,
#        1.9, 3. , 3. , 3.5, 3.3, 4.4, 3.4, 4.2, 4.1, 3.2, 3.5, 3.5, 3.8,
#        3.1, 3.6, 2.9, 2.9, 4. , 3.3, 3.1, 3.4, 3.6])

# %%
plt.hist(calculated_averages)
plt.xlabel(f'Average of {n_dice_per_experiment} dice rolls')
plt.ylabel('# of Occurances')
plt.title(f'Outcome of averaging {n_dice_per_experiment} dice rolls {n_experiments} times')
# Out:
# Text(0.5, 1.0, 'Outcome of averaging 10 dice rolls 100 times')

# %% [markdown]
# This concept allows us to make calculations using the normal distribution based on the values we calculate from our samples.

# %% [markdown]
# Null and Alternate Hypothesis
# When performing formal statistical hypothesis testing, the question being asked needs to be phrased as a **null hypothesis** and an **alternative hypothesis**. The null hypothesis, is the "status quo", and usually reflects no change or no difference, while the alternative hypothesis says that there is a difference or change.

# %% [markdown]
# Some examples:
#
# - `H0`: There is no difference in right-handed people and left-handed individual's heights.Ha: There is a difference in right-handed people and left-handed individual's heights.
# - `H0`: The amount of sleep a student gets the night before an exam makes no difference on the student's exam score.
# - `Ha`: Less sleep the night before an exam leads to a lower exam score.

# %% [markdown]
# The results of a hypothesis test will lead us to either **reject the null hypothesis**, or **fail to reject** the null hypothesis. Strictly speaking, this does not tell us that the alternative hypothesis is true.
#
# The alternative hypothesis can either be that there is a difference or that the difference is either grater or less than. This tells us whether we are setting up a **two-tailed** (for any difference) or **one-tailed** (for a specific difference) test.

# %% [markdown]
# ## Hypothesis Test Results
# We choose a **confidence interval**, a range of values within we are sure our statistic will fall a certain percent of the time, for our testing before we begin. By choosing a confidence interval, we set our **significance level**, α (alpha) as well. α is defined as 1 - our confidence level. Typical values for our confidence interval are 95%, 99% and 99.9%.

# %% [markdown]
# ### p-values
# One of the values we will obtain from a hypothesis test is a p-value. The calculation differs depending on the specific type of test we are running, but is interpreted the same way.
#
# The p-value is the chance that we obtained the results we did (or would obtain more extreme results) due to chance if the null hypothesis is true.
#
# For example, imagine we were testing the hypothesis that Codeup students that drink coffee have higher grades. Our hypotheses would be:
# - H0: There is no difference in grade for coffee and non-coffee drinkers.
# - Ha: Coffee drinkers have higher grades than non-coffee drinkers.
#
# Let's imagine we end up with a p-value of .05. This means that if it's true that there is no difference in grades, and we ran the experiment 20 times, we would expect 1 out of the 20 experiments to tell us that there is a difference in grades, purely due to chance.
#
# Based on our previously set confidence interval and p-value, we decide whether to reject the null hypothesis or not. If our p-value is less than
# α
# , we reject the null hypothesis, otherwise, we fail to reject the null hypothesis.
#
# Note that p-values don't tell us anything about effect size.

# %% [markdown]
# ## Hypothesis Testing Errors
# There are two types of errors we will encounter with hypothesis testing:
#
# - A type I error is when we reject the null hypothesis, but, in reality, the null hypothesis is true.
# - A type II error is when we fail to reject the null hypothesis when it is actually false.
#
# The table below shows us the possible outcomes of a hypothesis test.

# %% [markdown]
# ![Screen%20Shot%202021-02-11%20at%209.37.07%20AM.png](attachment:Screen%20Shot%202021-02-11%20at%209.37.07%20AM.png)

# %% [markdown]
# # Lets see some code!

# %%
from pydataset import data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy import stats

# %%
df = data("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 1         16.99  1.01  Female     No   Sun  Dinner     2
# 2         10.34  1.66    Male     No   Sun  Dinner     3
# 3         21.01  3.50    Male     No   Sun  Dinner     3
# 4         23.68  3.31    Male     No   Sun  Dinner     2
# 5         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3
# 241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 243       17.82  1.75    Male     No   Sat  Dinner     2
# 244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## One tailed t test example ( compare a subgroup to the population)
# - business question
#     - are tipes on Sunday significantly diffent that the rest of the week?
#         - The null hypothesis
#             - that there is no difference (tips are the same on sunday versus the entire week)
#         - The alternative hypotheisis
#             - that the is a differnece between Sunday tips and the entire week.
#
# compare the means

# %%
null_hypothesis = "Sunday tips are the same as the rest of the week"
alternative_hypothesis = "Sunday tips are different than the rest of the week's"
confidence_level = .95
alpha = 1 - confidence_level
#set your alpha early so you dont try and lasso in results this is just fudged up

# %%
# make a subroup fr Sunday
sunday = df[df.day == "Sun"]
sunday.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# lets take a peek at the Sunday tip
sunday.tip.hist()
# you get a nice little histogram of the sunday tips
# Out:
# <AxesSubplot:>

# %%
df.tip.hist()
#use the whole tip hist and compare it to sundays
# Out:
# <AxesSubplot:>

# %%
# if you are doing a one-tailed test, use the ttest_1samp() function
# using 1 tailed test vs 2 tailed because we are comparing a subgroup to a population so if you are comparing to sub it would be 2 but since it is 1 sub and a full it is 1 taile
t, p = stats.ttest_1samp(sunday.tip, df.tip.mean())
#this will compare the histograms underneath the hood

# %%
alpha
# its the fraction that never ends *sna snao*
# Out:
# 0.050000000000000044

# %%
p
# so close to alpha
# this is why you set alpha first
# Out:
# 0.0737884052452269

# %%
if p > alpha:
    print("We reject the null hypothesis", null_hypothesis)
    print("We move forward with the alternative hypothesis that", alternative_hypothesis)
else:
    print("We fail to reject the null hypothesis")
    print("Failing the reject the null != 'accepting the null'")
# Out:
# We reject the null hypothesis Sunday tips are the same as the rest of the week
# We move forward with the alternative hypothesis that Sunday tips are different than the rest of the week's

# %% [markdown]
# ### Another example!!! WOOHOO!!!
